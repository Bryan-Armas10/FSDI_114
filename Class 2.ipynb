# %%
# DATA STRUCTURES

# %%
# Stack and Queues

# %%
# Simplified implementation of Stack and Queue
# Simplified refers to the fact  that these are using built-ins 
# Note: These are intended to give us a guide on how we could build these from scratch
 
class Stack:
    def __init__(self):
        self.items = []

    def push(self, element):
        self.item.append(element)

    def pop(selg):
        return self.item.pop()

    # Nice to have method
    def is_empty(self):
        return self.item == []

    def size(self):
        return len(self.items) 

    def peek(self):
        return self.items[len(self.items)==1]

class Queuse:
    def __init__(self):
        self.items = []

    def enqueue(self, element):
        self.items.insert(0, element)

    def dequeue(self):
        return self.items.pop()

    # Nice to have methods
    def is_empty(self):
        return self.items == []

    def size(self):
        return len(self.items)

    def peek(self):
        return self.items[len(self.items)==1]

# %%
# From scratch implementation of Stack

class StackII:
    class __Node:
        def __init__(self, datum):
            self.data = datum

    def __init__(self):
        self.top = None

    def push(self, element):
        new_node = self.__Node(element)
        if not self.top:           # this is the same as if self.top = None
            self.top = new_node
        else:
            new_node.below = self.top
            self.top = new_node

    def pop(self):
        if self.top:
            datum = self.top.data
            self.top = self.top.below
            return datum
        raise IndexError("The stack is emppty!")

    def is_empty(self):
        return self.top == None

    def size(self):
        count = 0
        current = self.top
        while current:                # While current is not equal to None 
            count += 1
            current = current.below
        return count

    def peek(self):
        return self.top.data

# %%
##### Homework Assignment: Stacks and Queues

######## Definitions and Use Cases

# a. Define what a stack is and provide at least two real-world examples where stacks are used.
# Stack A stack is a linear data structure that follows the LIFO (Last In, First Out) principle, meaning the last element added is the first one 
# to be removed.

# Real-world examples:
# Stack of plates: When you stack plates, the last plate placed will be the first one to be taken off.
# Undo in a text editor: When you use the undo option, the most recent action you performed is the first to be reversed, which implies a stack 
# structure.

# b. Define what a queue is and provide at least two real-world examples where queues are used.
# Queue A queue is a linear data structure that follows the FIFO (First In, First Out) principle, meaning the first element added is the first 
# one to be removed.

# Real-world examples:
# Bank line: People are served in the order they arrived; the first to arrive is the first to be served.
# Print queue: Print jobs are managed in the order they were sent to the printer.
   
######## Primary Operations

# a. List and explain the primary operations performed on a stack.
# push(): Adds an element to the top of the stack.
# pop(): Removes and returns the element from the top of the stack.
# top(): Views the element at the top of the stack without removing it.
# isEmpty(): Checks if the stack is empty.
    
# b. List and explain the primary operations performed on a queue.
# enqueue(): Adds an element to the end of the queue.
# dequeue(): Removes and returns the element at the front of the queue.
# front(): Views the element at the front of the queue without removing it.
# isEmpty(): Checks if the queue is empty.
    
######## Key Differences
# Compare and contrast the behavior of stacks and queues in terms of their insertion and removal mechanisms. Use examples to illustrate your 
# vexplanation.

# Stack:
# Insertion (push) and removal (pop) occur at the same end (top).
# Operation order: LIFO (Last In, First Out).

# Queue:
# Insertion (enqueue) happens at the rear, and removal (dequeue) occurs at the front.
# Operation order: FIFO (First In, First Out).

# Example:
# Stack: If we add elements A, B, C to the stack, the order of removal will be C, B, A.
# Queue: If we add elements A, B, C to the queue, the order of removal will be A, B, C.

######## Variations
# Research and describe at least one variation of a stack (e.g., bounded stack) and one variation of a queue (e.g., circular queue). Explain 
# how they differ from the basic versions.

# Limited Stack:
# A limited stack is a stack with a maximum number of elements it can hold. If more elements are pushed than allowed, the stack raises an 
# error or returns a "stack full" signal.

# b. Circular Queue:
# A circular queue solves the problem of wasted space in a regular queue when elements are removed but space is still available. In a circular 
# queue, the end of the queue connects to the front, forming a circle, allowing more efficient use of space.

######## Implementation
        
# a. Write pseudocode or explain how a stack can be implemented using an array or a linked list.
#class Node:
#    data
#    next

#class Stack:
#    top = None

#    def push(value):
#        new_node = Node(value)
#        new_node.next = top
#        top = new_node

#    def pop():
#        if top is None:
#            return "Stack is empty"
#        value = top.data
#        top = top.next
#        return value

#    def top_element():
#        return top.data if top is not None else "Stack is empty"

        
# b. Write pseudocode or explain how a queue can be implemented using an array or a linked list.
#class Node:
#    data
#    next

#class Queue:
#    front = None
#    rear = None

#    def enqueue(value):
#        new_node = Node(value)
#        if rear is not None:
#            rear.next = new_node
#        rear = new_node
#        if front is None:
#            front = new_node

#    def dequeue():
#        if front is None:
#            return "Queue is empty"
#        value = front.data
#        front = front.next
#        if front is None:
#            rear = None
#        return value


######## Time Complexity
# Discuss the time complexity of common operations (e.g., push, pop, enqueue, dequeue) for stacks and queues. Explain any differences you observe.
# Stacks:
# push(): O(1) – Insertion at the top.
# pop(): O(1) – Removal from the top.
# top(): O(1) – Accessing the top element.

# Queues:
# enqueue(): O(1) – Insertion at the rear.
# dequeue(): O(1) – Removal from the front.
# front(): O(1) – Accessing the front element.
# Both structures have constant time operations O(1), but stacks operate on a single end (top) while queues operate on both ends (front and rear).

######## Real-World Applications
# Compare how stacks and queues are used in computer science, specifically in areas like memory management, process scheduling, or data buffering.
# Stacks:
# Memory management: In operating systems, stacks are used for managing function calls and returns, especially in recursive function calls.
# Undo in text editors: A stack is used to store previous states of a document and reverse actions in reverse order.
                                                                                                
# Queues:
# Process scheduling: Processes waiting to be executed are managed using a queue (FIFO).
# Data buffering: Queues are used for buffering data between different components, such as in network transmission.

######## Reversing a Queue with a Stack
# Explain how you can use a stack to reverse the order of elements in a queue. Provide a step-by-step description or pseudocode.
#function reverseQueue(q):
#    stack = Stack()
#    while not q.isEmpty():
#        stack.push(q.dequeue())
    
#    while not stack.isEmpty():
#        q.enqueue(stack.pop())

######## Data Structure Selection
# Given the following scenarios, decide whether a stack or queue would be more appropriate and justify your answer:

# a. Undo functionality in a text editor.
#The undo operation (reversing the most recent action) is a typical stack operation (LIFO).

# b. Managing tasks in a printer’s job queue.
# Print jobs should be served in the order they were sent, following the FIFO principle.

# c. Depth-first traversal of a graph.
# A depth-first search (DFS) algorithm typically uses a stack.

# d. First-come, first-served customer service.
#People should be served in the order they arrive, which follows the FIFO principle.

######## Advanced Concepts
# Research and explain what a deque (double-ended queue) is. How does it differ from a standard queue and a stack? Provide at least one example 
# of its practical use.

# A deque (double-ended queue) is a data structure that allows insertion and removal of elements from both ends (front and rear). It differs 
# from both stacks and queues because the latter allow operations at only one end.

# Example of use: A browser history could be implemented using a deque, where new links can be added either to the front or the rear of 
# the history list.
